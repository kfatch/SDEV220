# %% [markdown]
# 7.4:

# %%
things = ["mozzarella", "cinderella", "salmonella"]

# %% [markdown]
# 7.5:

# %%
things[1] = things[1].capitalize()
print(things)
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# Yes, the element was capitalized.

# %% [markdown]
# 7.6:

# %%
things[0] = things[0].upper()
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# 7.7:

# %%
del things[2]
print(things)
# Out:
# ['MOZZARELLA', 'Cinderella']

# %% [markdown]
# 9.1:

# %%
def good():
    list = ['Harry', 'Ron', 'Hermione']
    print(list)

# %% [markdown]
# 9.2:

# %%
def get_odds():
    list = []
    for num in range(10):
        if num % 2 == 1:
            list.append(num)
    print(list[2])
