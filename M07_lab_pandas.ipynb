# %%
import pandas as pd

# %%
pd.

# %% [markdown]
# CSV - CREATE

# %%
df = pd.read_csv('telco_churn.csv')

# %%
tempdict = {'col1': [1,2,3], 'col2':[4,5,6], 'col3':[7,8,9]}

# %%
dictdf = pd.DataFrame.from_dict(tempdict)

# %% [markdown]
# CSV - READ

# %% [markdown]
# READ - SHOW TOP AND BOTTOM ROWS

# %%
df.head(10)

# %%
dictdf.head()

# %%
df.tail(15)

# %% [markdown]
# READ - SHOW COLUMNS AND DATA TYPES

# %%
df.columns

# %%
df.dtypes

# %% [markdown]
# READ - SUMMARY

# %%
df.describe()

# %%
df.describe(include='object')

# %% [markdown]
# READ - FILTERING COLUMNS

# %%
df.State

# %%
df['International plan']

# %%
df['State', 'International plan']

# %%
df.State.unique()

# %% [markdown]
# READ - FILTERING ROWS

# %%
df[df['International plan']=='No']

# %%
df[(df['International plan']=='No') & df[df['Churn']==False]]

# %% [markdown]
# READ - INDEXING WITH ILOC

# %%
df.iloc[14]

# %%
df.iloc[14,-1]

# %%
df.iloc[22:33]

# %% [markdown]
# READ - FILTERING WITH LOC

# %%
state = df.copy()
state.set_index('State', inplace=True)

# %%
state.head()

# %%
state.loc['OH']

# %% [markdown]
# UPDATE

# %% [markdown]
# UPDATE - DROP ROWS

# %%
df.isnull().sum()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %% [markdown]
# UPDATE - DROP COLUMNS

# %%
df.drop('Area code', axis=1)

# %% [markdown]
# UPDATE - CREATE COLUMNS

# %%
df['New Column'] = df['Total night minutes'] + df['Total intl minutes']

# %% [markdown]
# UPDATE - ENITRE COLUMN

# %%
df['New Column'] = 100

# %%
df.head()

# %% [markdown]
# UPDATE - UPDATE SINGLE VALUE

# %%
df.iloc[0,-1] = 10

# %%
df.head()

# %% [markdown]
# UPDATE - CONDITION BASED UPDATING USING APPLY

# %%
df['Churn Binary'] = df['Churn'].apply(lambda x: 1 if x==True else 0)

# %%
df[df['Churn']==True].head()

# %% [markdown]
# DELETE

# %% [markdown]
# DELETE - OUTPUT TO CSV

# %%
df.to_csv('output.csv')

# %% [markdown]
# DELETE - OUTPUT TO JSON

# %%
df.to_json()

# %% [markdown]
# DELETE - OUTPUT TO HTML

# %%
df.to_html()

# %% [markdown]
# DELETE A DATAFRAME

# %%
del df
